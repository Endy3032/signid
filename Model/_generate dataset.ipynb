# %%
import csv
import cv2
import matplotlib.animation as animation
import matplotlib.pyplot as plt
import mediapipe as mp
import numpy as np
import os
import pandas as pd
from random import uniform
from utils import drawLandmarks

# %matplotlib inline

# %%
if not os.path.exists("./preview"):
	os.makedirs("./preview")

# %% [markdown]
# ### get dataset source videos

# %%
dataset = {}
alphabet = [d.path for d in os.scandir("./dataset") if d.is_dir()]

for path in alphabet:
	dataset[os.path.basename(path)] = [f.path for f in os.scandir(path) if f.is_file() and f.name.endswith(".mp4")]

# %%
HandLandmarker = mp.tasks.vision.HandLandmarker

options = mp.tasks.vision.HandLandmarkerOptions(
	base_options=mp.tasks.BaseOptions(model_asset_path="./models/hand_landmarker.task"),
	running_mode=mp.tasks.vision.RunningMode.VIDEO,
	num_hands=2,
)

# %% [markdown]
# ### generating data cache for each video

# %%
for path in dataset:
	for file in dataset[path]:
		if file == "nan":
			continue

		cache_file = f"{file}.csv"

		if os.path.exists(cache_file):
			print(f"Cache found, skipping {file}")
			continue

		with HandLandmarker.create_from_options(options) as landmarker:
			print(f"Processing {file}")
			vid = cv2.VideoCapture(file)

			if not vid.isOpened():
				print(f"Error opening {file}")
				continue

			fps = vid.get(cv2.CAP_PROP_FPS)
			inc = 1000 / fps
			i = 0

			video_data = []

			while True:
				ret, frame = vid.read()
				if not ret:
					print(f"Finished {file}")
					break

				mp_img = mp.Image(image_format=mp.ImageFormat.SRGB, data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
				result = landmarker.detect_for_video(mp_img, int(i))
				landmarks_ls = result.hand_world_landmarks
				handedness_ls = result.handedness

				if not landmarks_ls:
					i += inc
					continue

				for idx in range(len(landmarks_ls)):
					landmarks = pd.Series(np.array([[landmark.x, landmark.y, landmark.z] for landmark in landmarks_ls[idx]]).flatten())
					handedness = handedness_ls[idx][0].index

					landmarks = landmarks.tolist()

					video_data.append([path, handedness] + landmarks)

				if i == 0:
					output = drawLandmarks(mp_img.numpy_view(), result)
					cv2.imwrite(f"./preview/{os.path.basename(file)}.jpg", cv2.cvtColor(output, cv2.COLOR_RGB2BGR))

				i += inc

			vid.release()

			if video_data:
				with open(cache_file, "w", newline="") as f:
					writer = csv.writer(f)
					header = ["letter", "hand"] + [f"{coord}{i}" for i in range(21) for coord in ["x", "y", "z"]]
					writer.writerow(header)
					writer.writerows(video_data)
# Out:
# Cache found, skipping ./dataset/R/IMG_4864.mp4
# Cache found, skipping ./dataset/R/IMG_4681.mp4
# Cache found, skipping ./dataset/R/IMG_3945.mp4
# Cache found, skipping ./dataset/R/IMG_3833.mp4
# Cache found, skipping ./dataset/R/IMG_3773.mp4
# Cache found, skipping ./dataset/R/IMG_3999.mp4
# Cache found, skipping ./dataset/R/IMG_5557.mp4
# Cache found, skipping ./dataset/R/IMG_4890.mp4
# Cache found, skipping ./dataset/U/IMG_4867.mp4
# Cache found, skipping ./dataset/U/IMG_5560.mp4
# Cache found, skipping ./dataset/U/IMG_4684.mp4
# Cache found, skipping ./dataset/U/IMG_3776.mp4
# Cache found, skipping ./dataset/U/IMG_3836.mp4
# Cache found, skipping ./dataset/U/IMG_4003.mp4
# Cache found, skipping ./dataset/U/IMG_4893.mp4
# Cache found, skipping ./dataset/I/IMG_5549.mp4
# Cache found, skipping ./dataset/I/IMG_3763.mp4
# Cache found, skipping ./dataset/I/IMG_3991.mp4
# Cache found, skipping ./dataset/I/IMG_3823.mp4
# Cache found, skipping ./dataset/I/IMG_4701.mp4
# Cache found, skipping ./dataset/I/IMG_4880.mp4
# Cache found, skipping ./dataset/I/IMG_3889.mp4
# Cache found, skipping ./dataset/I/IMG_4670.mp4
# Cache found, skipping ./dataset/I/IMG_4856.mp4
# Cache found, skipping ./dataset/N/IMG_4860.mp4
# Cache found, skipping ./dataset/N/IMG_3995.mp4
# Cache found, skipping ./dataset/N/IMG_3941.mp4
# Cache found, skipping ./dataset/N/IMG_3769.mp4
# Cache found, skipping ./dataset/N/IMG_3828.mp4
# Cache found, skipping ./dataset/N/IMG_4885.mp4
# Cache found, skipping ./dataset/N/IMG_4676.mp4
# Cache found, skipping ./dataset/N/IMG_4705.mp4
# Cache found, skipping ./dataset/N/IMG_5553.mp4
# Cache found, skipping ./dataset/G/IMG_5576.mp4
# Cache found, skipping ./dataset/G/IMG_3887.mp4
# Cache found, skipping ./dataset/G/IMG_3761.mp4
# Cache found, skipping ./dataset/G/IMG_3821.mp4
# Cache found, skipping ./dataset/G/IMG_3989.mp4
# Cache found, skipping ./dataset/G/IMG_4878.mp4
# Cache found, skipping ./dataset/G/IMG_4667.mp4
# Cache found, skipping ./dataset/G/IMG_4698.mp4
# Cache found, skipping ./dataset/G/IMG_4854.mp4
# Cache found, skipping ./dataset/G/IMG_5584.mp4
# Cache found, skipping ./dataset/G/IMG_5547.mp4
# Cache found, skipping ./dataset/T/IMG_4683.mp4
# Cache found, skipping ./dataset/T/IMG_4866.mp4
# Cache found, skipping ./dataset/T/IMG_5559.mp4
# Cache found, skipping ./dataset/T/IMG_3775.mp4
# Cache found, skipping ./dataset/T/IMG_3947.mp4
# Cache found, skipping ./dataset/T/IMG_3835.mp4
# Cache found, skipping ./dataset/T/IMG_4002.mp4
# Cache found, skipping ./dataset/T/IMG_4892.mp4
# Cache found, skipping ./dataset/S/IMG_4682.mp4
# Cache found, skipping ./dataset/S/IMG_4865.mp4
# Cache found, skipping ./dataset/S/IMG_5558.mp4
# Cache found, skipping ./dataset/S/IMG_3946.mp4
# Cache found, skipping ./dataset/S/IMG_3774.mp4
# Cache found, skipping ./dataset/S/IMG_3834.mp4
# Cache found, skipping ./dataset/S/IMG_4001.mp4
# Cache found, skipping ./dataset/S/IMG_4891.mp4
# Cache found, skipping ./dataset/A/IMG_4872.mp4
# Cache found, skipping ./dataset/A/IMG_4848.mp4
# Cache found, skipping ./dataset/A/IMG_3881.mp4
# Cache found, skipping ./dataset/A/IMG_3982.mp4
# Cache found, skipping ./dataset/A/IMG_3811.mp4
# Cache found, skipping ./dataset/A/IMG_3754.mp4
# Cache found, skipping ./dataset/A/IMG_3752.mp4
# Cache found, skipping ./dataset/A/IMG_3753.mp4
# Cache found, skipping ./dataset/A/IMG_4689.mp4
# Cache found, skipping ./dataset/A/IMG_5541.mp4
# Cache found, skipping ./dataset/A/IMG_4658.mp4
# Cache found, skipping ./dataset/F/IMG_3886.mp4
# Cache found, skipping ./dataset/F/IMG_4695.mp4
# Cache found, skipping ./dataset/F/IMG_4877.mp4
# Cache found, skipping ./dataset/F/IMG_3760.mp4
# Cache found, skipping ./dataset/F/IMG_3820.mp4
# Cache found, skipping ./dataset/F/IMG_3988.mp4
# Cache found, skipping ./dataset/F/IMG_4853.mp4
# Cache found, skipping ./dataset/F/IMG_4666.mp4
# Cache found, skipping ./dataset/F/IMG_5546.mp4
# Cache found, skipping ./dataset/O/IMG_4861.mp4
# Cache found, skipping ./dataset/O/IMG_3830.mp4
# Cache found, skipping ./dataset/O/IMG_3770.mp4
# Cache found, skipping ./dataset/O/IMG_3942.mp4
# Cache found, skipping ./dataset/O/IMG_3996.mp4
# Cache found, skipping ./dataset/O/IMG_3829.mp4
# Cache found, skipping ./dataset/O/IMG_5580.mp4
# Cache found, skipping ./dataset/O/IMG_4886.mp4
# Cache found, skipping ./dataset/O/IMG_5554.mp4
# Cache found, skipping ./dataset/O/IMG_4677.mp4
# Cache found, skipping ./dataset/O/IMG_5586.mp4
# Cache found, skipping ./dataset/O/IMG_4706.mp4
# Cache found, skipping ./dataset/#/IMG_5571.mp4
# Cache found, skipping ./dataset/H/IMG_4669.mp4
# Cache found, skipping ./dataset/H/IMG_5548.mp4
# Cache found, skipping ./dataset/H/IMG_3762.mp4
# Cache found, skipping ./dataset/H/IMG_3990.mp4
# Cache found, skipping ./dataset/H/IMG_3822.mp4
# Cache found, skipping ./dataset/H/IMG_4700.mp4
# Cache found, skipping ./dataset/H/IMG_4879.mp4
# Cache found, skipping ./dataset/H/IMG_4855.mp4
# Cache found, skipping ./dataset/H/IMG_5591.mp4
# Cache found, skipping ./dataset/H/IMG_5585.mp4
# Cache found, skipping ./dataset/H/IMG_3888.mp4
# Cache found, skipping ./dataset/M/IMG_3892.mp4
# Cache found, skipping ./dataset/M/IMG_4859.mp4
# Cache found, skipping ./dataset/M/IMG_3826.mp4
# Cache found, skipping ./dataset/M/IMG_3827.mp4
# Cache found, skipping ./dataset/M/IMG_3994.mp4
# Cache found, skipping ./dataset/M/IMG_3768.mp4
# Cache found, skipping ./dataset/M/IMG_4675.mp4
# Cache found, skipping ./dataset/M/IMG_4884.mp4
# Cache found, skipping ./dataset/M/IMG_5552.mp4
# Cache found, skipping ./dataset/M/IMG_4704.mp4
# Cache found, skipping ./dataset/C/IMG_3883.mp4
# Cache found, skipping ./dataset/C/IMG_4874.mp4
# Cache found, skipping ./dataset/C/IMG_4692.mp4
# Cache found, skipping ./dataset/C/IMG_3979.mp4
# Cache found, skipping ./dataset/C/IMG_3984.mp4
# Cache found, skipping ./dataset/C/IMG_3757.mp4
# Cache found, skipping ./dataset/C/IMG_3816.mp4
# Cache found, skipping ./dataset/C/IMG_4661.mp4
# Cache found, skipping ./dataset/C/IMG_5543.mp4
# Cache found, skipping ./dataset/C/IMG_4850.mp4
# Cache found, skipping ./dataset/D/IMG_3884.mp4
# Cache found, skipping ./dataset/D/IMG_4875.mp4
# Cache found, skipping ./dataset/D/IMG_4693.mp4
# Cache found, skipping ./dataset/D/IMG_3818.mp4
# Cache found, skipping ./dataset/D/IMG_3758.mp4
# Cache found, skipping ./dataset/D/IMG_4851.mp4
# Cache found, skipping ./dataset/D/IMG_4663.mp4
# Cache found, skipping ./dataset/V/IMG_5561.mp4
# Cache found, skipping ./dataset/V/IMG_4685.mp4
# Cache found, skipping ./dataset/V/IMG_3777.mp4
# Cache found, skipping ./dataset/V/IMG_3837.mp4
# Cache found, skipping ./dataset/V/IMG_4004.mp4
# Cache found, skipping ./dataset/V/IMG_3948.mp4
# Cache found, skipping ./dataset/V/IMG_4868.mp4
# Cache found, skipping ./dataset/V/IMG_4894.mp4
# Cache found, skipping ./dataset/Q/IMG_5589.mp4
# Cache found, skipping ./dataset/Q/IMG_4680.mp4
# Cache found, skipping ./dataset/Q/IMG_4889.mp4
# Cache found, skipping ./dataset/Q/IMG_4863.mp4
# Cache found, skipping ./dataset/Q/IMG_3944.mp4
# Cache found, skipping ./dataset/Q/IMG_3832.mp4
# Cache found, skipping ./dataset/Q/IMG_3772.mp4
# Cache found, skipping ./dataset/Q/IMG_3998.mp4
# Cache found, skipping ./dataset/Q/IMG_5556.mp4
# Cache found, skipping ./dataset/Q/IMG_5596.mp4
# Cache found, skipping ./dataset/X/IMG_5563.mp4
# Cache found, skipping ./dataset/X/IMG_4870.mp4
# Cache found, skipping ./dataset/X/IMG_4687.mp4
# Cache found, skipping ./dataset/X/IMG_3950.mp4
# Cache found, skipping ./dataset/X/IMG_3839.mp4
# Cache found, skipping ./dataset/X/IMG_4006.mp4
# Cache found, skipping ./dataset/X/IMG_3779.mp4
# Cache found, skipping ./dataset/X/IMG_5583.mp4
# Cache found, skipping ./dataset/X/IMG_4896.mp4
# Cache found, skipping ./dataset/X/IMG_5590.mp4
# Cache found, skipping ./dataset/E/IMG_3885.mp4
# Cache found, skipping ./dataset/E/IMG_4694.mp4
# Cache found, skipping ./dataset/E/IMG_4876.mp4
# Cache found, skipping ./dataset/E/IMG_3819.mp4
# Cache found, skipping ./dataset/E/IMG_3987.mp4
# Cache found, skipping ./dataset/E/IMG_3759.mp4
# Cache found, skipping ./dataset/E/IMG_3981.mp4
# Cache found, skipping ./dataset/E/IMG_4852.mp4
# Cache found, skipping ./dataset/E/IMG_5545.mp4
# Cache found, skipping ./dataset/E/IMG_4665.mp4
# Cache found, skipping ./dataset/B/IMG_4873.mp4
# Cache found, skipping ./dataset/B/IMG_4691.mp4
# Cache found, skipping ./dataset/B/IMG_4849.mp4
# Cache found, skipping ./dataset/B/IMG_3882.mp4
# Cache found, skipping ./dataset/B/IMG_3978.mp4
# Cache found, skipping ./dataset/B/IMG_3983.mp4
# Cache found, skipping ./dataset/B/IMG_3756.mp4
# Cache found, skipping ./dataset/B/IMG_3755.mp4
# Cache found, skipping ./dataset/B/IMG_3812.mp4
# Cache found, skipping ./dataset/B/IMG_3815.mp4
# Cache found, skipping ./dataset/B/IMG_3814.mp4
# Cache found, skipping ./dataset/B/IMG_5542.mp4
# Cache found, skipping ./dataset/B/IMG_4659.mp4
# Cache found, skipping ./dataset/K/IMG_3890.mp4
# Cache found, skipping ./dataset/K/IMG_3992.mp4
# Cache found, skipping ./dataset/K/IMG_3824.mp4
# Cache found, skipping ./dataset/K/IMG_3764.mp4
# Cache found, skipping ./dataset/K/IMG_4702.mp4
# Cache found, skipping ./dataset/K/IMG_4673.mp4
# Cache found, skipping ./dataset/K/IMG_5550.mp4
# Cache found, skipping ./dataset/K/IMG_4857.mp4
# Cache found, skipping ./dataset/K/IMG_4881.mp4
# Cache found, skipping ./dataset/L/IMG_3891.mp4
# Cache found, skipping ./dataset/L/IMG_4858.mp4
# Cache found, skipping ./dataset/L/IMG_3825.mp4
# Cache found, skipping ./dataset/L/IMG_3767.mp4
# Cache found, skipping ./dataset/L/IMG_4674.mp4
# Cache found, skipping ./dataset/L/IMG_4703.mp4
# Cache found, skipping ./dataset/L/IMG_4883.mp4
# Cache found, skipping ./dataset/L/IMG_5551.mp4
# Cache found, skipping ./dataset/Y/IMG_4871.mp4
# Cache found, skipping ./dataset/Y/IMG_5564.mp4
# Cache found, skipping ./dataset/Y/IMG_3840.mp4
# Cache found, skipping ./dataset/Y/IMG_3951.mp4
# Cache found, skipping ./dataset/Y/IMG_4009.mp4
# Cache found, skipping ./dataset/Y/IMG_3780.mp4
# Cache found, skipping ./dataset/Y/IMG_4688.mp4
# Cache found, skipping ./dataset/Y/IMG_4897.mp4
# Cache found, skipping ./dataset/P/IMG_4679.mp4
# Cache found, skipping ./dataset/P/IMG_4862.mp4
# Cache found, skipping ./dataset/P/IMG_4888.mp4
# Cache found, skipping ./dataset/P/IMG_3831.mp4
# Cache found, skipping ./dataset/P/IMG_3943.mp4
# Cache found, skipping ./dataset/P/IMG_3771.mp4
# Cache found, skipping ./dataset/P/IMG_3997.mp4
# Cache found, skipping ./dataset/P/IMG_5595.mp4
# Cache found, skipping ./dataset/P/IMG_5555.mp4
# Cache found, skipping ./dataset/P/IMG_5592.mp4
# Cache found, skipping ./dataset/W/IMG_5562.mp4
# Cache found, skipping ./dataset/W/IMG_4686.mp4
# Cache found, skipping ./dataset/W/IMG_3838.mp4
# Cache found, skipping ./dataset/W/IMG_4005.mp4
# Cache found, skipping ./dataset/W/IMG_3778.mp4
# Cache found, skipping ./dataset/W/IMG_3949.mp4
# Cache found, skipping ./dataset/W/IMG_4869.mp4
# Cache found, skipping ./dataset/W/IMG_4895.mp4

# %% [markdown]
# ### combine all data cache files

# %%
columns = ["letter", "hand"]
for i in range(21):
	columns.append(f"x{i}")
	columns.append(f"y{i}")
	columns.append(f"z{i}")

if os.path.exists("dataset.csv"):
	i = 1
	while os.path.exists(f"dataset.csv.bak{i}"):
		i += 1
	os.rename("dataset.csv", f"dataset.csv.bak{i}")

with open("dataset.csv", "w", newline="") as f:
	csv.writer(f).writerow(columns)

# %%
blacklist = set()

for path in dataset:
	for file in dataset[path]:
		cache_file = f"{file}.csv"

		if not os.path.exists(cache_file):
			print(f"Cache not found, skipping {file}")
			blacklist.add(os.path.basename(file))
			continue

		if os.path.basename(file) in blacklist:
			print(f"File in blacklist, skipping {file}")
			continue

		try:
			with open(cache_file, "r") as f:
				reader = csv.reader(f)
				header = next(reader)
				data = list(reader)

				with open("dataset.csv", "a", newline="") as f:
					writer = csv.writer(f)
					for row in data:
						for idx in range(2, len(row)):
							row[idx] = str(float(row[idx]) + uniform(-0.0001, 0.0001))
						writer.writerow(row)

		except Exception as e:
			print(f"Error processing {file}: {e}")
			blacklist.append(os.path.basename(file))
			continue

# %% [markdown]
# ### split dataset

# %%
letters = list("ABCDEFGHIKLMNOPQRSTUVWXY#")

print("Reading CSV...")
df = pd.read_csv("dataset.csv")

expected_cols = ["letter", "hand"] + [f"{coord}{i}" for i in range(21) for coord in ["x", "y", "z"]]
if list(df.columns) != expected_cols:
	raise ValueError(f"Expected columns {expected_cols}, got {list(df.columns)}")

print("Splitting train/test...")
train_data = []
test_data = []

for letter in letters:
	letter_data = df[df["letter"] == letter]

	train_sample = letter_data.sample(n=int(len(letter_data) * 0.8), random_state=42)
	remaining = letter_data.drop(train_sample.index)
	test_sample = remaining.sample(n=len(remaining), random_state=42)

	print(f"Letter {letter}: Train {len(train_sample)}, Test {len(test_sample)}")

	train_data.append(train_sample)
	test_data.append(test_sample)

train_df = pd.concat(train_data, ignore_index=True)
train_df = train_df.sample(frac=1, random_state=42).reset_index(drop=True)  # Shuffle
test_df = pd.concat(test_data, ignore_index=True)
test_df = test_df.sample(frac=1, random_state=42).reset_index(drop=True)  # Shuffle

print("Saving to train.csv and test.csv...")
train_df.to_csv("train.csv", index=False)
test_df.to_csv("test.csv", index=False)

print(f"Done! Train rows: {len(train_df)}, Test rows: {len(test_df)}")
# Out:
# Reading CSV...
# Splitting train/test...
# Letter A: Train 2808, Test 703
# Letter B: Train 3004, Test 751
# Letter C: Train 2704, Test 677
# Letter D: Train 1766, Test 442
# Letter E: Train 2856, Test 715
# Letter F: Train 2577, Test 645
# Letter G: Train 2858, Test 715
# Letter H: Train 3218, Test 805
# Letter I: Train 2423, Test 606
# Letter K: Train 2428, Test 608
# Letter L: Train 2024, Test 506
# Letter M: Train 2786, Test 697
# Letter N: Train 2355, Test 589
# Letter O: Train 3006, Test 752
# Letter P: Train 2963, Test 741
# Letter Q: Train 2722, Test 681
# Letter R: Train 2292, Test 574
# Letter S: Train 2228, Test 557
# Letter T: Train 2493, Test 624
# Letter U: Train 1989, Test 498
# Letter V: Train 2226, Test 557
# Letter W: Train 2302, Test 576
# Letter X: Train 2764, Test 692
# Letter Y: Train 2252, Test 563
# Letter #: Train 201, Test 51
# Saving to train.csv and test.csv...
# Done! Train rows: 61245, Test rows: 15325
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### visualize

# %%
landmarks = pd.Series()
with HandLandmarker.create_from_options(options) as landmarker:
	file = "./dataset/V/IMG_3837.mp4"
	print(file)
	vid = cv2.VideoCapture(file)

	if not vid.isOpened():
		print(f"Error opening {file}")
		exit

	ret, frame = vid.read()
	mp_img = mp.Image(image_format=mp.ImageFormat.SRGB, data=cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

	result = landmarker.detect_for_video(mp_img, 0)
	landmarks_ls = result.hand_world_landmarks

	for idx in range(len(landmarks_ls)):
		landmarks = pd.Series(np.array([[landmark.x, landmark.y, landmark.z] for landmark in landmarks_ls[idx]]).flatten())

	vid.release()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.view_init(elev=10, azim=255)
ax.set_xlim(-0.1, 0.1)
ax.set_ylim(-0.1, 0.1)
ax.set_zlim(-0.1, 0.1)
ax.set_xlabel("X")
ax.set_ylabel("Z")
ax.set_zlabel("Y")

frames = 360
fps = 30


def update(frame):
	ax.view_init(elev=10 + np.sin(np.radians(360 / frames * frame * 2)) * 10, azim=360 / frames * frame)


colors = ["cyan", "orchid", "deepskyblue", "lime", "orange", "k", "k"]

lines = [np.array([landmarks[j : j + 3] for j in range(i, i + 12, 3)]) for i in range(3, 63, 12)]
lines.append(np.array([landmarks[0:3], landmarks[3:6]]))
lines.append(np.array([landmarks[0:3], *[landmarks[j : j + 3] for j in range(15, 63, 12)], landmarks[0:3]]))
for i in range(len(lines)):
	line = lines[i]
	ax.plot(line[:, 0], line[:, 2], -line[:, 1] * 1.25, color=colors[i])

for j in range(0, 63, 3):
	ax.scatter(
		landmarks[j],
		landmarks[j + 2],
		-landmarks[j + 1] * 1.25,
		color=colors[int((j / 3 - 1) // 4)] if j != 0 else "k",
	)

ani = animation.FuncAnimation(fig, update, frames=frames, interval=1000 / fps)  # Rotate 360°
ani.save("hand.gif", writer="ffmpeg", fps=fps, progress_callback=(lambda i, n: print(f"Progress: {i}/{n}")))

plt.show()
